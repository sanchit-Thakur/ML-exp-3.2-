# %% [markdown]
# <a href="https://colab.research.google.com/github/sanchit-Thakur/ML-exp-3.2-/blob/main/MLexp_3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn as sklearn
df = pd.read_csv("/content/student_performance_dataset.csv")
print(data)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
print(df)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
df.describe()
# Out:
#         student_id  study_time_hours  attendance_percent  sleep_hours  \
# count  1000.000000       1000.000000         1000.000000  1000.000000
# mean    500.500000          3.570700           85.092300     6.799500
# std     288.819436          1.478559            9.270685     1.203527
# min       1.000000          0.500000           54.800000     3.200000
# 25%     250.750000          2.600000           78.800000     5.900000
# 50%     500.500000          3.600000           85.200000     6.800000
# 75%     750.250000          4.500000           91.900000     7.600000
# max    1000.000000          8.100000          100.000000    10.000000
#
#        previous_grade  final_exam_score
# count     1000.000000       1000.000000
# mean        69.740900         83.543500
# std         12.613425         10.341333
# min         31.300000         46.800000
# 25%         61.000000         76.075000
# 50%         69.600000         83.800000
# 75%         78.400000         91.525000
# ...

# %%
df.fillna(0)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
df.head(9)
# Out:
#    student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0           1    Male               4.0                98.0          6.5
# 1           2  Female               6.3               100.0          5.7
# 2           3    Male               4.9                85.3          7.9
# 3           4    Male               2.6                77.5          8.0
# 4           5    Male               2.2                89.6          4.6
# 5           6  Female               4.2                78.2          5.7
# 6           7    Male               1.5               100.0          5.0
# 7           8    Male               6.2                86.4          6.0
# 8           9    Male               5.3                81.3          6.7
#
#   parental_education internet_access extracurricular_activities part_time_job  \
# 0          Bachelors             Yes                        Yes            No
# 1        High School             Yes                        Yes           Yes
# ...

# %%
df.tail(6)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 994         995  Female               4.5                75.4          9.4
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# 994          Bachelors             Yes                        Yes
# 995            Masters             Yes                        Yes
# 996                NaN              No                        Yes
# 997        High School             Yes                        Yes
# 998        High School              No                         No
# ...

# %%
df.fillna(method = 'ffill')
# Out:
# /tmp/ipykernel_3708/1145651979.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'ffill')
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# ...

# %%
df.fillna(method = 'bfill')
# Out:
# /tmp/ipykernel_3708/3673297803.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'bfill')
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# ...

# %%
df.shape
# Out:
# (1000, 12)

# %%
x = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x
# Out:
# array([[1, 'Male', 4.0, ..., 'No', 76.9, 100.0],
#        [2, 'Female', 6.3, ..., 'Yes', 75.5, 100.0],
#        [3, 'Male', 4.9, ..., 'Yes', 88.5, 97.3],
#        ...,
#        [998, 'Female', 2.6, ..., 'Yes', 65.2, 79.2],
#        [999, 'Female', 4.6, ..., 'Yes', 52.2, 82.2],
#        [1000, 'Male', 3.9, ..., 'No', 45.4, 70.4]], dtype=object)

# %%
y
# Out:
# array(['A', 'A', 'A', 'B', 'D', 'B', 'D', 'B', 'B', 'C', 'D', 'C', 'B',
#        'A', 'C', 'B', 'B', 'C', 'B', 'A', 'C', 'A', 'C', 'C', 'A', 'C',
#        'C', 'A', 'B', 'B', 'B', 'B', 'A', 'A', 'A', 'A', 'B', 'B', 'B',
#        'A', 'C', 'C', 'A', 'C', 'C', 'D', 'D', 'B', 'B', 'D', 'A', 'B',
#        'C', 'B', 'A', 'B', 'C', 'B', 'C', 'B', 'B', 'C', 'B', 'C', 'B',
#        'A', 'D', 'C', 'C', 'B', 'C', 'C', 'A', 'C', 'A', 'D', 'C', 'C',
#        'C', 'B', 'A', 'C', 'D', 'A', 'A', 'D', 'C', 'A', 'C', 'B', 'C',
#        'B', 'A', 'B', 'A', 'C', 'B', 'B', 'D', 'C', 'C', 'D', 'B', 'A',
#        'B', 'A', 'C', 'C', 'A', 'C', 'D', 'A', 'C', 'C', 'A', 'A', 'F',
#        'A', 'C', 'C', 'A', 'B', 'C', 'B', 'B', 'A', 'B', 'D', 'B', 'B',
#        'A', 'C', 'C', 'B', 'B', 'A', 'F', 'B', 'B', 'B', 'B', 'C', 'B',
#        'D', 'B', 'D', 'B', 'F', 'D', 'D', 'B', 'C', 'B', 'C', 'A', 'B',
#        'B', 'B', 'D', 'C', 'B', 'C', 'A', 'A', 'B', 'B', 'A', 'B', 'C',
# ...

# %%
x_train
# Out:
# array([[688, 'Male', 1.6, ..., 'No', 88.7, 74.4],
#        [501, 'Male', 4.4, ..., 'No', 53.6, 76.1],
#        [333, 'Female', 3.0, ..., 'Yes', 93.2, 82.8],
#        ...,
#        [630, 'Male', 3.8, ..., 'No', 65.2, 81.3],
#        [560, 'Female', 1.9, ..., 'Yes', 80.4, 73.5],
#        [685, 'Male', 3.4, ..., 'No', 70.2, 83.8]], dtype=object)

# %%
y_train
# Out:
# array(['C', 'C', 'B', 'A', 'B', 'A', 'C', 'B', 'D', 'C', 'C', 'C', 'B',
#        'C', 'B', 'C', 'D', 'A', 'C', 'D', 'B', 'C', 'D', 'B', 'C', 'A',
#        'B', 'B', 'B', 'B', 'A', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'C', 'C', 'C', 'A', 'F', 'B', 'A', 'B', 'A', 'B', 'C', 'B', 'A',
#        'D', 'C', 'D', 'C', 'B', 'A', 'C', 'B', 'A', 'A', 'A', 'B', 'C',
#        'B', 'B', 'D', 'A', 'C', 'D', 'C', 'A', 'A', 'B', 'A', 'A', 'B',
#        'B', 'C', 'A', 'A', 'A', 'C', 'B', 'A', 'B', 'B', 'B', 'C', 'A',
#        'B', 'A', 'C', 'B', 'B', 'B', 'C', 'C', 'D', 'A', 'C', 'B', 'C',
#        'C', 'C', 'C', 'A', 'B', 'B', 'C', 'C', 'B', 'C', 'A', 'C', 'D',
#        'D', 'C', 'D', 'C', 'C', 'B', 'F', 'A', 'C', 'B', 'B', 'A', 'C',
#        'C', 'C', 'B', 'D', 'C', 'A', 'B', 'F', 'C', 'A', 'B', 'A', 'C',
#        'B', 'B', 'A', 'D', 'D', 'B', 'A', 'B', 'B', 'B', 'B', 'B', 'A',
#        'B', 'D', 'B', 'C', 'C', 'C', 'B', 'B', 'C', 'A', 'C', 'C', 'C',
# ...

# %%
x_test
# Out:
# array([[994, 'Female', 6.2, ..., 'No', 75.4, 92.7],
#        [860, 'Male', 1.7, ..., 'Yes', 80.0, 66.5],
#        [299, 'Male', 1.7, ..., 'No', 67.9, 69.2],
#        ...,
#        [216, 'Male', 2.1, ..., 'No', 58.9, 74.7],
#        [654, 'Male', 5.1, ..., 'Yes', 58.8, 74.8],
#        [151, 'Male', 2.2, ..., 'No', 66.2, 84.7]], dtype=object)

# %%
y_test
# Out:
# array(['A', 'D', 'D', 'B', 'B', 'C', 'A', 'A', 'B', 'A', 'C', 'A', 'A',
#        'B', 'B', 'B', 'B', 'B', 'C', 'C', 'B', 'A', 'B', 'D', 'A', 'C',
#        'D', 'A', 'F', 'A', 'A', 'A', 'A', 'F', 'B', 'A', 'B', 'B', 'A',
#        'B', 'A', 'A', 'A', 'B', 'A', 'C', 'A', 'C', 'C', 'B', 'A', 'B',
#        'B', 'C', 'B', 'C', 'D', 'C', 'B', 'B', 'A', 'C', 'B', 'B', 'A',
#        'C', 'A', 'B', 'C', 'C', 'A', 'B', 'D', 'C', 'A', 'B', 'D', 'A',
#        'A', 'B', 'C', 'D', 'C', 'C', 'B', 'A', 'A', 'A', 'B', 'A', 'A',
#        'B', 'A', 'F', 'B', 'B', 'C', 'A', 'C', 'B', 'A', 'B', 'A', 'C',
#        'C', 'A', 'A', 'C', 'B', 'B', 'B', 'D', 'C', 'A', 'A', 'C', 'A',
#        'C', 'A', 'C', 'C', 'A', 'C', 'C', 'B', 'B', 'B', 'B', 'C', 'F',
#        'C', 'C', 'B', 'A', 'D', 'B', 'A', 'B', 'B', 'A', 'D', 'A', 'D',
#        'D', 'A', 'B', 'B', 'C', 'A', 'A', 'C', 'B', 'B', 'B', 'D', 'B',
#        'B', 'D', 'A', 'A', 'C', 'B', 'B', 'B', 'A', 'A', 'B', 'D', 'B',
# ...
